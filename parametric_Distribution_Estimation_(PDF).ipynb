# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal   # normal function is used to generate the normal distribution data from numpy
sample = normal(loc=50, scale=5, size=1000) # Mean is {loc=50}, Standard deviation is {scale=5}, size of Data is {size=1000}

# %%
sample.mean()
# Out:
# np.float64(49.88433235720983)

# %%
sample.std()
# Out:
# np.float64(5.015281007237605)

# %%
# plot histogram to understand the distribution of data
plt.hist(sample,bins=10)
# Out:
# (array([ 10.,  42., 134., 217., 256., 202.,  97.,  23.,  16.,   3.]),
#  array([35.45058016, 38.7390338 , 42.02748745, 45.31594109, 48.60439474,
#         51.89284838, 55.18130202, 58.46975567, 61.75820931, 65.04666296,
#         68.3351166 ]),
#  <BarContainer object of 10 artists>)

# %%
# Calculate sample Mean and sample Std Deviation
sample_mean = sample.mean()
sample_std = sample.std()

# %%
from scipy.stats import norm
dist = norm(sample_mean, sample_std)

# %%
values = np.linspace(sample.min(),sample.max(),100)

# %%
sample.max()
# Out:
# np.float64(68.33511659982118)

# %%
sample.min()
# Out:
# np.float64(35.45058016054334)

# %%
probabilities = [dist.pdf(value) for value in values]

# %%
plt.hist(sample,bins=10,density=True)
plt.plot(values,probabilities)
